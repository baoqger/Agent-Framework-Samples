# %% [markdown]
# # 🐍 AI Travel Agent with Microsoft Agent Framework (Python)
#
# ## 📋 Scenario Overview
#
# This notebook demonstrates how to build an intelligent travel planning agent using the Microsoft Agent Framework for Python. The agent leverages GitHub Models to automatically generate personalized day-trip itineraries for random destinations worldwide.
#
# **Key Features:**
# - 🎲 **Smart Destination Selection**: Custom tool function for random destination picking
# - 🗺️ **Detailed Itinerary Generation**: AI-powered travel planning with local recommendations
# - 🔄 **Async Processing**: Uses asyncio for efficient API communication
# - 🛠️ **Tool Integration**: Demonstrates function calling capabilities in AI agents
#
# ## 🏗️ Technical Implementation
#
# ### Core Components
# - **Agent Framework**: Python implementation of Microsoft's agent orchestration system
# - **GitHub Models API**: Access to state-of-the-art language models via GitHub's inference service
# - **OpenAI Compatibility**: Uses OpenAI client patterns with GitHub Models backend
# - **Environment Management**: Secure credential handling with python-dotenv
#
# ### Architecture Flow
# ```python
# User Request → ChatAgent → GitHub Models API ↔ get_random_destination()
#                      ↓
#               Travel Itinerary Response
# ```
#
# ### Key Classes & Methods
# - `ChatAgent`: Main conversational agent orchestrator
# - `OpenAIChatClient`: GitHub Models API client wrapper
# - `get_random_destination()`: Custom tool function for destination selection
# - Environment variables: Secure API configuration management
#
# ## ⚙️ Prerequisites & Setup
#
# **Required Dependencies:**
# ```bash
#
# pip install agent-framework-core -U
# ```
#
# **Environment Configuration (.env file):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# **GitHub Models Access:**
# 1. Sign up for GitHub Models access
# 2. Generate a personal access token
# 3. Configure environment variables as shown above
#
# ## 🚀 Usage Instructions
#
# Execute the cells below in sequence to:
# 1. Import required libraries and load environment variables
# 2. Define the random destination generator tool
# 3. Create and configure the AI agent
# 4. Run travel planning requests and view results
#
# Let's build an intelligent travel planning assistant! 🌟

# %%
# ! pip install -r ../../../Installation/requirements.txt -U

# %%
# 📦 Import Required Libraries
# Standard library imports for system operations and random number generation
import os
from random import randint

# Third-party library for loading environment variables from .env file
from dotenv import load_dotenv

# %%
# 🤖 Import Microsoft Agent Framework Components
# ChatAgent: The main agent class for conversational AI
# OpenAIChatClient: Client for connecting to OpenAI-compatible APIs (including GitHub Models)
from agent_framework import Agent
from agent_framework.openai import OpenAIChatCompletionClient

# %%
# 🔧 Load Environment Variables
# This loads configuration from a .env file in the project root
# Required variables: GITHUB_ENDPOINT, GITHUB_TOKEN, GITHUB_MODEL_ID
load_dotenv()
# Out:
# True

# %%
# 🎲 Tool Function: Random Destination Generator
# This function will be available to the agent as a tool
# The agent can call this function to get random vacation destinations
def get_random_destination() -> str:
    """Get a random vacation destination.
    
    Returns:
        str: A randomly selected destination from our predefined list
    """
    # List of popular vacation destinations around the world
    destinations = [
        "Barcelona, Spain",
        "Paris, France", 
        "Berlin, Germany",
        "Tokyo, Japan",
        "Sydney, Australia",
        "New York, USA",
        "Cairo, Egypt",
        "Cape Town, South Africa",
        "Rio de Janeiro, Brazil",
        "Bali, Indonesia"
    ]
    # Return a random destination from the list
    return destinations[randint(0, len(destinations) - 1)]

# %%
# 🔗 Create OpenAI Chat Client for GitHub Models
# This client connects to GitHub Models API (OpenAI-compatible endpoint)
# Environment variables required:
# - GITHUB_ENDPOINT: API endpoint URL (usually https://models.inference.ai.azure.com)
# - GITHUB_TOKEN: Your GitHub personal access token
# - GITHUB_MODEL_ID: Model to use (e.g., gpt-4o-mini, gpt-4o)
openai_chat_client = OpenAIChatCompletionClient(
    base_url=os.environ.get("GITHUB_ENDPOINT"),
    api_key=os.environ.get("GITHUB_TOKEN"), 
    model=os.environ.get("GITHUB_MODEL_ID")
)

# %%
# 🤖 Create the Travel Planning Agent
# This creates a conversational AI agent with specific capabilities:
# - client: The AI model client for generating responses
# - instructions: System prompt that defines the agent's personality and role
# - tools: List of functions the agent can call to perform actions
agent = Agent(
    client=openai_chat_client,
    instructions="You are a helpful AI Agent that can help plan vacations for customers at random destinations.",
    tools=[get_random_destination]  # Our random destination tool function
)

# %%
# 🚀 Run the Agent
# Send a message to the agent and get a response
# The agent will use its tools (get_random_destination) if needed
response = await agent.run("Plan me a day trip")

# %%
# 📋 View Raw Response Object
# This shows the complete response structure including metadata
# Useful for debugging and understanding the response format
response

# %%
# 📖 Extract and Display the Travel Plan
# Get the last message from the conversation (agent's response)s
last_message = response.messages[-1]
# Extract the text content from the message
text_content = last_message.contents[0].text
# Display the formatted travel plan
print("🏖️ Travel plan:")
print(text_content)
# Out:
# 🏖️ Travel plan:
# Here’s a well-paced one-day itinerary in Tokyo, blending classic sights with modern neighborhoods. I’ve included timing, transit, food ideas, ticket tips, and easy swaps based on interests or weather.
#
# Morning: Asakusa and Skytree (tradition + views)
# - 8:00 – Senso-ji Temple (Asakusa)
#   - Arrive early to beat crowds. Walk Nakamise-dori for snacks (taiyaki, senbei) and souvenirs.
#   - Shrine etiquette: rinse hands at the basin; a light bow is fine. No photos in inner prayer areas if signs say so.
# - 9:30 – Sumida Park stroll
#   - Riverside views of Tokyo Skytree; nice in cherry blossom season.
# - 10:15 – Tokyo Skytree
#   - Walk or take the Tobu Skytree Line from Asakusa. Ride up for citywide views.
#   - Tickets: reserve online for a timed entry if possible (Tembo Deck + Tembo Galleria for highest views).
#   - Optional: Sumida Aquarium in Skytree Town if you love aquariums.
#
# Lunch and market vibes: Ueno/Ameyoko
# - 12:30 – Ueno/Okachimachi (Ameya-Yokocho)
#   - Metro: Asakusa → Ueno via Ginza Line (~5 min).
#   - Grab lunch at a standing sushi bar, ramen shop, or yakitori stall. Browse the lively street market for snacks and bargains.
#   - Optional (time permitting): Ueno Park quick loop or a focused 60–90 min at Tokyo National Museum.
#
# Afternoon: Shrine and street fashion or pop culture
# Option A: Harajuku/Meiji Jingu + Omotesando
# - 14:30 – Meiji Jingu Shrine
#   - JR Ueno → Harajuku via Yamanote Line (~26 min). Calm forested paths; a nice reset.
# - 15:30 – Takeshita Street
#   - Crepes, thrift shops, quirky boutiques. For design and architecture, stroll Omotesando (Nezu Museum is a serene stop if you like art/gardens).
# Option B: Akihabara (if you’re into anime/gadgets)
# - 14:30 – Akihabara
#   - Explore retro game shops, figure stores, and electronics megastores. Good coffee stops and curry/gyoza shops around.
#
# Golden hour and neon: Shibuya and Shinjuku
# - 17:00 – Shibuya
#   - Harajuku → Shibuya on JR Yamanote (~2 min). See Hachiko and the Scramble Crossing.
#   - Optional: Shibuya Sky for sunset views (reserve timed entry).
# - 19:00 – Shinjuku dinner and nightlife
#   - Shibuya → Shinjuku on JR Yamanote (~7 min).
#   - Eat: Omoide Yokocho (yakitori/izakayas), or a ramen favorite (Ichiran for solo booths, or locals’ picks like Nagi/Mutekiya).
#   - Night options: Golden Gai for tiny bars, Kabukicho for lights (stick to main streets), or the free Tokyo Metropolitan Government Building observatory if you skipped other viewpoints.
#
# Simple rain-friendly swaps
# - Museums: Ueno (Tokyo National Museum, National Museum of Nature and Science), Mori Art Museum (Roppongi).
# - teamLab Planets (Toyosu): immersive digital art; prebook a timeslot.
# - Department store food halls (depachika): Daimaru Tokyo, Isetan Shinjuku, Tokyu Food Show (Shibuya).
#
# Getting around quickly
# - IC card: Use Suica/PASMO (Apple/Google Wallet supports Mobile Suica). Tap in/out on JR/Metro/buses.
# - Pass: If you’ll ride a lot, consider a 24-hour Tokyo Subway Ticket.
# - Typical ride times: Asakusa→Ueno ~5 min; Ueno→Harajuku ~26 min; Harajuku→Shibuya ~2 min; Shibuya→Shinjuku ~7 min.
#
# Budget snapshot (per person, JPY)
# - Transit: 1,000–1,500
# - Food/snacks: 4,000–8,000 (casual to nice)
# - Observatories: Skytree 2,100–3,000; Shibuya Sky ~2,000–2,500
# - Museums (optional): 500–1,000 each
# - Total typical day: 8,000–18,000 depending on choices
#
# Practical tips
# - Cash/card: Cards widely accepted, but small stalls may be cash-only. IC card works at many kiosks.
# - Etiquette: Stand left on most escalators (right in Osaka), quiet on trains, don’t eat while walking in crowded areas.
# - Trash bins are scarce—carry a small bag for trash.
# - Connectivity: Pocket Wi‑Fi or eSIM helps with maps/transit. Google Maps/Citymapper are reliable.
# - Last trains: Usually around 00:00–01:00; taxis are safe but pricier.
#
# Want this tailored? Tell me:
# - Travel date/season
# - Pace (leisurely vs. packed)
# - Interests (foodie, art, anime, shopping, gardens, architecture)
# - Dietary needs and budget
# - Whether you prefer fewer transfers or walking
# - Any mobility considerations or traveling with kids
