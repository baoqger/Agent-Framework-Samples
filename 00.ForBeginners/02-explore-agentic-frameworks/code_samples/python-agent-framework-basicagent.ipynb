# %% [markdown]
# # 🔍 Exploring Agentic Frameworks - Basic Agent (Python)
#
# ## 📋 Learning Objectives
#
# This notebook explores the fundamental concepts of the Microsoft Agent Framework through a basic agent implementation. You'll learn core agentic patterns and understand how intelligent agents work under the hood.
#
# **What You'll Discover:**
# - 🏗️ **Agent Architecture**: Understanding the basic structure of AI agents
# - 🛠️ **Tool Integration**: How agents use external functions to extend capabilities
# - 💬 **Conversation Flow**: Managing multi-turn conversations and context
# - 🔧 **Configuration Patterns**: Best practices for agent setup and management
#
# ## 🎯 Key Concepts Covered
#
# ### Agentic Framework Principles
# - **Autonomy**: How agents make independent decisions
# - **Reactivity**: Responding to environmental changes and user inputs
# - **Proactivity**: Taking initiative based on goals and context
# - **Social Ability**: Interacting through natural language
#
# ### Technical Components
# - **ChatAgent**: Core agent orchestration and conversation management
# - **Tool Functions**: Extending agent capabilities with custom functions
# - **OpenAI Integration**: Leveraging language models through standardized APIs
# - **Environment Management**: Secure configuration and credential handling
#
# ## ⚙️ Prerequisites & Setup
#
# **Required Dependencies:**
# ```bash
#
# pip install agent-framework-core  -U
# ```
#
# **Environment Configuration (.env file):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# ## 🔧 Technical Stack
#
# **Core Technologies:**
# - Microsoft Agent Framework (Python)
# - GitHub Models API integration
# - OpenAI-compatible client patterns
# - Environment-based configuration
#
# **Agent Capabilities:**
# - Natural language understanding and generation
# - Function calling and tool usage
# - Context-aware responses
# - Extensible architecture
#
# ## 📚 Framework Comparison
#
# This example demonstrates the Microsoft Agent Framework approach compared to other agentic frameworks:
#
# | Feature | Microsoft Agent Framework | Other Frameworks |
# |---------|-------------------------|------------------|
# | **Integration** | Native Microsoft ecosystem | Varied compatibility |
# | **Simplicity** | Clean, intuitive API | Often complex setup |
# | **Extensibility** | Easy tool integration | Framework-dependent |
# | **Enterprise Ready** | Built for production | Varies by framework |
#
# ## 🚀 Getting Started
#
# Follow the cells below to build your first basic agent and understand foundational agentic concepts!

# %%
# ! pip install -r ../../../Installation/requirements.txt -U

# %%
# 📚 Exploring Agentic Frameworks - Basic Agent Example
# This example demonstrates core concepts of the Microsoft Agent Framework

# 📦 Import Required Libraries
import os                     # For environment variable access
from random import randint    # For generating random selections

from dotenv import load_dotenv  # For loading .env configuration files

# %%
# 🤖 Import Core Agent Framework Components
# ChatAgent: The main conversational agent class
# OpenAIChatClient: Client for connecting to OpenAI-compatible APIs
from agent_framework import Agent
from agent_framework.openai import OpenAIChatCompletionClient

# %%
# 🔧 Initialize Environment Configuration
# Load environment variables from .env file
# This enables secure storage of API keys and endpoints
load_dotenv()
# Out:
# True

# %%
# 🛠️ Tool Function: Random Destination Generator
# This demonstrates how to create tools that agents can use
# Tools extend the agent's capabilities beyond just conversation
def get_random_destination() -> str:
    """Get a random vacation destination.
    
    This function serves as a tool that the agent can call when it needs
    to suggest a random destination for travel planning.
    
    Returns:
        str: A randomly selected destination from the predefined list
    """
    # Curated list of popular vacation destinations worldwide
    destinations = [
        "Barcelona, Spain",
        "Paris, France", 
        "Berlin, Germany",
        "Tokyo, Japan",
        "Sydney, Australia",
        "New York, USA",
        "Cairo, Egypt",
        "Cape Town, South Africa",
        "Rio de Janeiro, Brazil",
        "Bali, Indonesia"
    ]
    # Return a randomly selected destination
    return destinations[randint(0, len(destinations) - 1)]

# %%
# 🔗 Create OpenAI Chat Client
# This demonstrates how to connect to GitHub Models (OpenAI-compatible API)
# The client handles all communication with the AI model
openai_chat_client = OpenAIChatCompletionClient(
    base_url=os.environ.get("GITHUB_ENDPOINT"),    # API endpoint URL
    api_key=os.environ.get("GITHUB_TOKEN"),        # Authentication token
    model=os.environ.get("GITHUB_MODEL_ID")  # Model identifier (e.g., gpt-4o-mini)
)

# %%
# 🤖 Create the Basic Agent
# This demonstrates the core agent creation pattern in the framework
# Key components: chat client, instructions, and tools
agent = Agent(
    client=openai_chat_client,  # The AI model client for generating responses
    instructions="You are a helpful AI Agent that can help plan vacations for customers at random destinations.",  # System prompt defining agent behavior
    tools=[get_random_destination]   # List of available tools the agent can use
)

# %%
session = agent.create_session()

# %%
response1 = await agent.run("Plan me a day trip",session= session)

# %%
last_message = response1.messages[-1]
text_content = last_message.contents[0].text
print("Travel plan:")
print(text_content)
# Out:
# Travel plan:
# How about a spontaneous day trip to a random destination: Cairo, Egypt. Here’s a first‑timer’s one‑day plan that balances the pyramids, museum time, old markets, and the Nile. If you’d prefer a different destination or pace, I can rework it.
#
# Overview
# - Focus: Giza Pyramids, Egyptian history highlights, Islamic Cairo, Nile at sunset
# - Best season: October–April (cooler). In summer, start earlier to beat heat.
# - Getting around: Pre-book a private driver for the day or use Uber/Careem. Cairo traffic is unpredictable—build in buffers.
#
# Itinerary (with options)
# - 6:30–7:15: Pickup and quick breakfast
#   - Grab foul/taameya (Egyptian falafel) and fresh juice from a local spot (e.g., Zooba or a neighborhood bakery).
# - 7:30–10:45: Giza Plateau (Pyramids and Sphinx)
#   - See the Great Pyramid (outside; optional interior), Khafre pyramid, Sphinx.
#   - Optional: short camel or horse ride from official stables; agree on price first.
#   - Tip: Buy tickets only at official booths; ignore aggressive touts. A licensed guide can enrich the visit.
# - 11:15–12:30: Pyramid-view lunch
#   - 9 Pyramids Lounge (reserve if possible) or a simpler local restaurant nearby; or quick koshary if you want more museum time.
# - Choose your afternoon focus:
#   - Option A (Museums + Old Cairo):
#     - 13:15–15:00: Egyptian Museum (Tahrir) for classics (including King Tut artifacts) or NMEC (Fustat) for the Royal Mummies Hall.
#     - 15:30–17:00: Islamic Cairo wander
#       - Khan el-Khalili bazaar, Al-Muizz Street monuments; mint tea or coffee at El Fishawy.
#       - Dress modestly if entering mosques; ask about photography rules.
#   - Option B (More ancient sites):
#     - 13:00–15:00: Saqqara (Step Pyramid of Djoser) and quick dash to Dahshur (Bent or Red Pyramid) if you’re archaeology-keen.
#     - 16:00–17:00: Brief stroll in Coptic Cairo (Hanging Church, Ben Ezra Synagogue) time permitting.
# - 17:45–18:45: Sunset on the Nile
#   - Felucca sail from Zamalek or near the Opera House docks. If mobility is a concern, opt for a motorboat with easier boarding.
# - 19:30: Dinner
#   - Abou El Sid (classic Egyptian), Zooba (casual modern Egyptian), or Naguib Mahfouz Restaurant in Khan (atmospheric).
# - Optional nightcap/view
#   - Cairo Tower lookout (check hours) or a rooftop in Zamalek.
#
# Transport and timing notes
# - Giza ↔ Downtown: 45–75 minutes depending on traffic.
# - Downtown ↔ Islamic/Coptic Cairo or Zamalek: 20–45 minutes.
# - Private driver day rate: convenient for stash-and-go and time savings.
#
# Estimated budget (very rough; check current prices)
# - Private driver (8–10 hours): $50–90
# - Giza entry: roughly $10–20; Great Pyramid interior extra
# - Museum tickets: roughly $5–15 each (Egyptian Museum or NMEC)
# - Camel ride (30–60 min): about $10–25 (agree beforehand)
# - Felucca (per boat, shared among your group): about $10–20 for ~1 hour
# - Meals: $5–20 per person per meal depending on venue
#
# Practical tips
# - Heat and sun: Hat, sunscreen, plenty of water; start early.
# - Cash: Carry small bills for tips and small purchases; cards accepted at many mid/high-end places.
# - Dress: Comfortable closed shoes; modest attire for religious sites (shoulders/knees covered; bring a light scarf).
# - Fridays: Midday prayers can affect mosque access and traffic.
# - Safety: Use rideshare or your driver; keep valuables close; decline unsolicited “help” with a polite “no, thanks.”
#
# Accessibility
# - Giza has uneven ground and slopes; panoramic viewpoints are reachable by car. Pyramid interiors have narrow passages.
# - Museums are generally more accessible (ramps/elevators), but verify before you go.
# - Feluccas often require stepping down into the boat; ask for a motorboat with easier boarding if needed.
#
# Want me to book/reserve anything (driver, guide, pyramid-view lunch, felucca) or tailor this to your interests (foodie, archaeology, shopping, photography), travel dates, and budget? I can also spin a new random destination if Cairo isn’t your vibe.

# %%
response2 = await agent.run("I don't like that destination. Plan me another vacation.",session= session)

# %%
last_message = response2.messages[-1]
text_content = last_message.contents[0].text
print("Change plan:")
print(text_content)
# Out:
# Change plan:
# Great—let’s switch it up. How about a spontaneous day trip to Rio de Janeiro, Brazil? Here’s a one‑day plan that blends iconic views, beach time, local food, and samba vibes. If you want a different random pick, say “spin again.”
#
# Overview
# - Focus: Christ the Redeemer, Sugarloaf, beaches (Copacabana/Ipanema), Lapa nightlife
# - Best season: May–Oct (milder, drier). Summer (Dec–Mar) is lively but hot/humid.
# - Getting around: Use Uber/99 or licensed taxis; Metro works well between beach zones and downtown. Traffic can snarl—buffer time.
#
# Itinerary (with options)
# - 7:30–8:15: Breakfast near the beach
#   - Pão de queijo and espresso at a padaria; try açaí bowl if you like something cold.
# - 8:30–10:30: Christ the Redeemer (Corcovado)
#   - Prebook the official train or van up. Go early for fewer crowds and clearer views.
#   - Weather check: If the statue is socked in with clouds, swap order with Sugarloaf.
# - 10:45–12:15: Sugarloaf Mountain (Pão de Açúcar)
#   - Cable cars to Morro da Urca and Sugarloaf summit. Stunning city-and-bay panoramas.
# - 12:30–13:30: Lunch in Urca
#   - Casual bar snacks at Bar Urca (sit on the seawall), or a simple seafood spot.
# - 13:45–15:45: Beach time (Copacabana or Ipanema)
#   - Rent chairs/umbrella; sip água de coco. For a quieter vibe, try Posto 8–9 in Ipanema; for classic scene, Copacabana Posto 4–5.
#   - Keep valuables minimal; use a waterproof pouch if you’ll swim.
# - 16:00–17:30: Vista point or culture option
#   - Option A: Two Brothers (Morro Dois Irmãos) hike for an epic overlook. Go with a guide; start from Vidigal. Allow ~1.5–2 h round-trip.
#   - Option B: Museum of Tomorrow + Olympic Boulevard street art (including the Kobra mural).
# - 18:00–19:00: Sunset at Arpoador
#   - Join locals clapping the sunset between Ipanema and Copacabana.
# - 19:30–21:00: Dinner
#   - Churrascaria (Fogo de Chão, Carretão) for all‑you‑can‑eat barbecue; or try feijoada or moqueca at a traditional restaurant.
# - 21:30–late: Lapa samba
#   - Live music at Rio Scenarium or a samba circle at Carioca da Gema. Thursday–Saturday is best; check cover charges and arrive with ID.
#
# Transport and timing notes
# - Corcovado ↔ Urca: 25–45 minutes.
# - Urca ↔ Ipanema/Copacabana: 15–30 minutes.
# - Beach ↔ Lapa/downtown: 20–40 minutes by car or Metro.
#
# Estimated budget (rough)
# - Corcovado train/van: ~$20–30
# - Sugarloaf cable car: ~$30
# - Chairs/umbrella on the beach: ~$5–10 per person
# - Meals: $8–30 per person depending on venue
# - Nightlife covers: $5–15
#
# Practical tips
# - Safety: Stick to well‑lit, busier areas; use rideshares at night; avoid taking valuables to the sand.
# - Sun: Strong year‑round—reapply sunscreen, hat, sunglasses; hydrate.
# - Weather: If rain/low clouds, prioritize museums and Lapa/Santa Teresa instead of viewpoints.
# - Dress: Casual; bring a light layer for breezy evenings.
# - Language: Basic Portuguese phrases help; card payments widely accepted, but carry a little cash.
#
# Accessibility
# - Corcovado and Sugarloaf have accessible options (elevators/ramps). Beaches have boardwalks; sand access can be challenging, though some postos offer adapted chairs.
# - Lapa venues vary; check ahead for ramps/elevators.
#
# Want me to tailor this to your interests (foodie, adventure, art, chill), your exact date, and budget—or should I spin another random destination?
