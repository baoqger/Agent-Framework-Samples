# %%
from agent_framework import Agent, Content, Message
from pathlib import Path
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential

# %%
import os
import base64
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
agent = Agent(
    client=FoundryChatClient(credential=AzureCliCredential()),
    name="VisionAgent",
    instructions="You are a image analysist, you get a image and need to respond with what you see in the picture.",
)

# %%
print("User: What do you see in this image? [Image provided]")
result = await agent.run(
    Content.from_uri(
        uri="https://images.unsplash.com/photo-1506905925346-21bda4d32df4?w=800",
        media_type="image/jpeg",
    )
)
print(f"Agent: {result.text}")
# Out:
# User: What do you see in this image? [Image provided]
# Agent: A high-elevation mountain landscape at sunrise or sunset. Snow-capped, jagged peaks run across the left and center of the frame, with warm orange-pink light striking their ridges. A deep valley is filled with a thick, low-lying sea of clouds or fog that spills toward the foreground. In the immediate foreground there are dark, rocky slopes and scree. The sky above is clear with a soft gradient from blue to warm tones near the horizon, creating a calm, dramatic atmosphere.
