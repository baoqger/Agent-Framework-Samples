# %%
from agent_framework import Agent, Content, Message
from pathlib import Path
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential

# %%
import os
import base64
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
agent = Agent(
    client=FoundryChatClient(credential=AzureCliCredential()),
    name="VisionAgent",
    instructions="You are a image analysist, you get a image and need to respond with what you see in the picture.",
)

# %%
print("User: What do you see in this image? [Image provided]")
result = await agent.run(
    Content.from_uri(
        uri="https://unsplash.com/photos/a-room-with-a-table-and-chairs-BdU_E9nv1yY",
        media_type="image/jpeg",
    )
)
print(f"Agent: {result.text}")
# Out:
# User: What do you see in this image? [Image provided]
# Agent: A wide alpine landscape at golden hour. Snow-capped, jagged mountain peaks rise on the left and center, catching warm pink-orange light from a low sun. The valley below is completely filled with a thick, low-lying layer of clouds or fog — a “sea of clouds” — that spills between the ridges. In the foreground there is a rocky, barren ridge with sparse vegetation. The sky above is mostly clear with soft pastel tones near the horizon. Overall the scene feels calm and expansive, with strong contrast between the warm-lit peaks and the cool, textured cloud layer.
