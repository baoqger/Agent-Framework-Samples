# %%
from agent_framework import Agent, Content, Message
from pathlib import Path
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential

# %%
import os
import base64
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
def create_sample_image() -> str:
    """Create a simple 1x1 pixel PNG image for testing."""
    # This is a tiny yellow pixel in PNG format
    png_data = "iVBORw0KGgoAAAANSUhEUgAAAAEAAAABCAYAAAAfFcSJAAAADUlEQVR42mP8/5+hHgAHggJ/PchI7wAAAABJRU5ErkJggg=="
    return f"data:image/png;base64,{png_data}"

# %%
client = FoundryChatClient(credential=AzureCliCredential())

# %%
image_uri = create_sample_image()
message = Message(
    role="user",
    contents=[
        Content.from_text(text="What's in this image?"),
        Content.from_uri(uri=image_uri, media_type="image/png"),
    ],
)
# response = await client.get_response([message])
# print(f"Image Response: {response}")
# Out:
# Image Response: The image appears completely black/blank — I can’t make out any objects or details. It may be a fully dark/underexposed image, a very low-resolution/empty file, or there was an upload error.
#
# If you want, you can:
# - Re-upload a higher-resolution or better-lit version
# - Describe what you expected to show, and I can help identify or enhance it
# - Ask me to try basic adjustments (brightness/contrast) and I’ll attempt to recover details.

# %%
agent = client.as_agent()
result = await agent.run(message)

# %%
print(result.text)
# Out:
# The image is almost entirely black with a single small, faint light-gray/white dot near the center. At this size and resolution it looks like a tiny speck/noise pixel — possibly a distant star/point of light, dust/spot on a scanner/ camera sensor, or a compression artifact.
#
# If you want a clearer answer, please upload a larger or higher-resolution version or tell me whether you'd like me to try contrast/brightness enhancement or zooming.
