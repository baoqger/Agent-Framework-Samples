# %%
# ! pip install -r ../../../../requirements.txt -U

# %%
import os
from dotenv import load_dotenv
from agent_framework import Agent
from agent_framework.foundry import FoundryChatClient
from azure.identity import AzureCliCredential

# %%
load_dotenv()
# Out:
# True

# %%
AgentName = "Search-Agent"
AgentInstructions = """You are a helpful assistant that can search the web for current information.
            Use the Bing search tool to find up-to-date information and provide accurate, well-sourced answers.
            Always cite your sources when possible."""

# %%
# Create web search tool
web_search_tool = FoundryChatClient.get_web_search_tool()

# Create agent with web search capabilities
agent = Agent(
    client=FoundryChatClient(credential=AzureCliCredential()),
    name=AgentName,
    instructions=AgentInstructions,
    tools=[web_search_tool],
)

query = "What is today's date and weather in Guangzhou?"
print(f"User: {query}")
result = await agent.run(query)
print(f"Agent: {result.text}")
# Out:
# User: What is today's date and weather in Guangzhou?
# Agent: Today is Thursday, July 30, 2026.
#
# Current weather in Guangzhou (summary): mostly cloudy, very humid, with showers/thunderstorms possible later today and warm temperatures in the upper 20s–low 30s °C (around mid‑80s °F). Sources reporting similar conditions and an increased chance of rain this afternoon/evening: AccuWeather, China Meteorological / weather.com.cn, and Meteoblue. ([accuweather.com](https://www.accuweather.com/en/cn/guangzhou/102255/hourly-weather-forecast/102255))
#
# Would you like a more exact current temperature, the hourly forecast for today, or a 3‑day outlook?
